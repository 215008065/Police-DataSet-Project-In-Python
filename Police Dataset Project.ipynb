# %% [markdown]
# # Working on real project with python

# %% [markdown]
# # (A part of Big Data Analysis)

# %% [markdown]
# # Police DataSet

# %%
#Library to use in the project
import pandas as pd
import numpy as np

# %%
#import the police dataset
Police_Data = pd.read_csv(r'C:\Users\USER 01\Desktop\Police_Data.csv')

# %%
Police_Data.head(2)
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
#
#    driver_age driver_race violation_raw violation  search_conducted  \
# 0        20.0       White      Speeding  Speeding             False
# 1        40.0       White      Speeding  Speeding             False
#
#   search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN     Citation       False      0-15 Min               False
# 1         NaN     Citation       False      0-15 Min               False

# %% [markdown]
# Instructions for Data Cleansing
#
# 1) Remove the column that only contains missing values

# %%
Police_Data.isnull()
# Out:
#        stop_date  stop_time  country_name  driver_gender  driver_age_raw  \
# 0          False      False          True          False           False
# 1          False      False          True          False           False
# 2          False      False          True          False           False
# 3          False      False          True          False           False
# 4          False      False          True          False           False
# ...          ...        ...           ...            ...             ...
# 65530      False      False          True          False           False
# 65531      False      False          True          False           False
# 65532      False      False          True          False           False
# 65533      False      False          True           True            True
# 65534      False      False          True          False           False
#
#        driver_age  driver_race  violation_raw  violation  search_conducted  \
# ...

# %%
Police_Data.isnull().sum() #is Na
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
drop_collumns = ['country_name']

# %%
Police_Data.notnull().sum() #no NA
# Out:
# stop_date             65535
# stop_time             65535
# country_name              0
# driver_gender         61474
# driver_age_raw        61481
# driver_age            61228
# driver_race           61475
# violation_raw         61475
# violation             61475
# search_conducted      65535
# search_type            2479
# stop_outcome          61475
# is_arrested           61475
# stop_duration         61475
# drugs_related_stop    65535
# dtype: int64

# %%
Police_Data.drop(columns=drop_collumns, inplace = True) #use inplace to make permanent change to the original dataframe

# %%
Police_Data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %% [markdown]
# 2) For Speeding, were Men or Woman stopped more often

# %%
Police_Data[(Police_Data['driver_gender'] == 'M') & (Police_Data['violation'] == 'Speeding')]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 6       4/1/2005     17:30             M          1969.0        36.0
# 8      7/13/2005     10:15             M          1970.0        35.0
# ...          ...       ...           ...             ...         ...
# 65516  12/6/2012     10:52             M          1988.0        24.0
# 65522  12/6/2012     14:17             M          1980.0        32.0
# 65523  12/6/2012     14:33             M          1967.0        45.0
# 65529  12/6/2012     16:00             M          1994.0        18.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
#
#       driver_race violation_raw violation  search_conducted search_type  \
# ...

# %%
Police_Data[(Police_Data['driver_gender'] == 'F') & (Police_Data['violation'] == 'Speeding')]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 4      3/14/2005     10:00             F          1984.0        21.0
# 7       6/6/2005     13:20             F          1986.0        19.0
# 11     7/13/2005     19:00             F          1966.0        39.0
# 13     7/18/2005     19:30             F          1984.0        21.0
# 19     7/24/2005     20:10             F          1958.0        47.0
# ...          ...       ...           ...             ...         ...
# 65521  12/6/2012     14:00             F          1992.0        20.0
# 65524  12/6/2012     15:06             F          1974.0        38.0
# 65527  12/6/2012     15:26             F          1981.0        31.0
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race violation_raw violation  search_conducted search_type  \
# ...

# %%
Police_Data.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested stop_duration  drugs_related_stop
# 0       False      0-15 Min               False
# 1       False      0-15 Min               False

# %%
# Or you can shortly use this methond
Police_Data[Police_Data.violation =='Speeding'].driver_gender.value_counts()
# Out:
# M    25517
# F    11686
# Name: driver_gender, dtype: int64

# %%
Police_Data.stop_time #extract a column from dataframe
# Out:
# 0         1:55
# 1         8:15
# 2        23:15
# 3        17:15
# 4        10:00
#          ...
# 65530    17:54
# 65531    22:22
# 65532    23:20
# 65533     0:23
# 65534     0:30
# Name: stop_time, Length: 65535, dtype: object

# %% [markdown]
# Question(Groupby)
#
# 3.Does gender affect who gets searched during a stop

# %%
Police_Data.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested stop_duration  drugs_related_stop
# 0       False      0-15 Min               False
# 1       False      0-15 Min               False

# %%
Police_Data.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
Police_Data.search_conducted.value_counts()
# Out:
# False    63056
# True      2479
# Name: search_conducted, dtype: int64

# %% [markdown]
# 4) What is the mean stop_duration

# %%
Police_Data.stop_duration.value_counts()
# Out:
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
#df['column_name'] = df['Column_name'].map({old:new, old:new})

Police_Data['stop_duration'].map({'0-15 Min': 7.5 , '16-30 Min': 24 , '30+ Min':45})
# Out:
# 0         7.5
# 1         7.5
# 2         7.5
# 3        24.0
# 4         7.5
#          ...
# 65530     7.5
# 65531     7.5
# 65532     7.5
# 65533     NaN
# 65534     7.5
# Name: stop_duration, Length: 65535, dtype: float64

# %%
#to save or make changes to the original dataframe:
# the map function take every item or variable that is the same as '' and replace it with the give after(:)
Police_Data['stop_duration'] = Police_Data['stop_duration'].map({'0-15 Min': 7.5 , '16-30 Min': 24 , '30+ Min':45})

# %% [markdown]
# Police_Data.head(4)

# %%
#df['Column_name'].mean()
Police_Data.stop_duration.mean()
# Out:
# 12.187420698181345

# %% [markdown]
# 5) Compare the age distribution for each violation

# %%
#using the groupby to compare the age violation of each distribution

Police_Data.groupby('driver_age').describe()
# Out:
#            driver_age_raw                                                  \
#                     count         mean       std     min      25%     50%
# driver_age
# 15.0                  5.0  1992.600000  1.516575  1991.0  1992.00  1992.0
# 16.0                 34.0  1992.088235  2.478607  1989.0  1990.00  1992.0
# 17.0                449.0  1991.144766  2.229865  1988.0  1989.00  1991.0
# 18.0               1345.0  1990.211896  2.203320  1987.0  1988.00  1990.0
# 19.0               2388.0  1989.463568  2.169390  1986.0  1988.00  1989.0
# ...                   ...          ...       ...     ...      ...     ...
# 83.0                  2.0  1926.000000  2.828427  1924.0  1925.00  1926.0
# 84.0                  3.0  1925.666667  1.154701  1925.0  1925.00  1925.0
# 85.0                  1.0  1927.000000       NaN  1927.0  1927.00  1927.0
# 86.0                  6.0  1923.166667  1.471960  1922.0  1922.00  1922.5
# ...

# %%
Police_Data.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0

# %%
L = [1,2,3,-5,6,7,-67]
m = L[0]
for i in L:
    if i < m:
        m=i
        idx = L.index(m)
print(idx, m)
# Out:
# 6 -67

# %%
L = [1,2,3,-5,6,7,8]
m = L[0]
idx = 0
c=0
for i in L:
    if i < m:
        m=i
        idx = c
    c+=1
print(idx, m)
# Out:
# 3 -5
